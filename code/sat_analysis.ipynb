# %% [markdown]
# # Determining  Most Effective Approach to Increase SAT Participation

# %% [markdown]
# -  What leads to a high SAT participation rate for a given state?
# -  Will an approach to a given state be applicable to another?
#
# ## Problem Statement
#
# ### Background:
# The College Board is an organization that administers one of the most widely used college entrance exams – the SAT. In recent years, however, states have been forgoing the SAT for their primary competitor – the ACT. To address their losing market share, College Board released a newly formatted SAT in March 2016. This new format is intended to more closely align with what students are currently learning and serve as a better aptitude measurement for college.
#
# In order to examine what changes the newly formatted SAT led to in regards to participation and to recommend ways of increasing participation, I analyzed SAT and ACT data in 2017 and 2018. The data includes participation rates, total scores, and section scores.
#
# ### Takeaways:
# States that have seen a sudden growth in participation or have reached 100% participation will be helpful in drawing these insights. Specifically, Colorado, Illinois and Idaho. As of 2018, they have a participation rate of 100%, 99% and 100%, respectively. Further investigation revealed two primary reasons for such high rates:
# -  **Statewide Testing Contracts**
#     -  The College Board recently secured testing contracts with both Colorado and Illinois, leading to an immediate participation increase in 2018.
#
#
# -  **SAT School Day**
#     -  The College Board does not currently have a contract with the state of Idaho to administer the SAT. However, SAT School Day is carried out within their school districts. This event is conducted during the weekday, on campus and free-of-charge. This only furthered inclined Idaho’s students to take the SAT, increasing participation rate from an already high 93% in 2017 to 100% in 2018.
#
# ### Recommendations:
# **Secure statewide testing contracts**: The dramatic increase in SAT participation for Colorado and Illinois within the span of two years demonstrates the importance of establishing state partnerships. Executing a contract leads to immediate results.
#
# **Implement SAT School Day**: Though securing testing contracts proves to be the most direct method in increasing participation rates, it may not the easiest nor fastest to attain. As an alternative, the College Board can choose to implement SAT School Day within more school districts. Idaho’s 100% participation rate in 2018 justifies the value of having such an event, especially for states that already have moderate to high SAT participation. Given the choice, students will prefer the convenience and accessibility provided by SAT School Day over the ACT.
#
# **Target relevant states**: The ideal outcome is to increase SAT participation rate in all states, but it’s not practical to target all of them. To properly allocate our resources, do not target states that are still contractually bound to ACT. Rather, direct efforts towards states that already show a propensity for the SAT or at least those that do not have a strong preference for either. Presenting the SAT and its free resources will more likely incline these states to make a temporary, if not permanent, change. California is a desirable target because participation is fairly distributed between the SAT and ACT.

# %% [markdown]
# ## Executive Summary
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ### Data Source:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_style('darkgrid')
sns.set_palette(palette='colorblind')
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# The `sat_2017.csv` and `act_2017.csv` files are read in and assigned to appropriately named panda dataframes.

# %%
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# We'll look at a snapshot of our dataframes.

# %%
sat_2017[:10]
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017[:10]
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### SAT 2017 Data
# The `sat_2017` dataframe consists of 5 columns:
#     1. State
#     2. Participation Rate
#     3. Average Evidence-Based Reading and Writing Score
#     4. Average Math Score
#     5. Average Total Score
#
# ##### Takeaways
# -  Participation rate varies drastically per state.
#     -  Alabama and Arkansas have less than 10% participation.
#     -  Connecticut, Delaware and District of Columbia have 100% participation.
# -  The average score per state for each section ranges from 400-600.
# -  The difference between section scores is minimal.
# -  States with higher participation rates have lower scores when compared to states with lower participation rates.
# -  The total is measured by taking the sum of the two sections.

# %% [markdown]
# #### ACT 2017 Data
# The `act_2017` dataframe consists of 7 columns:
#     1. State
#     2. Participation Rate
#     3. Average English
#     4. Average Math Score
#     5. Average Reading Score
#     6. Average Science Score
#     7. Average Composite(Total) Score
#
# ##### Takeaways
# -  Participation rate varies drastically per state.
#     -  Delaware has less than 20% participation.
#     -  Alabamba, Arkansas and Colorado have 100% participation.
# -  The average score per state for each section ranges from 18-26.
# -  The difference between section scores is minimal.
# -  States with higher participation rates have lower scores when compared to states with lower participation rates.
# - The composite(total) score is calculated by taking the average of all sections.
# -  Nationally, the participation rate is 60%, with an average composite score of 21.0.

# %% [markdown]
# #### SAT 2017 vs. ACT 2017
#
# ##### Similarities:
# -  Participation rate and average score per state have a negative correlation.
# -  Difference between section scores per state is minimal. A state with a high score average in one section tend to have a high score average in the other and vice versa.
#     -  In Colorado, the average SAT section scores are 606 and 595.
#     -  In the District of Columbia, the average SAT score for both section are low, at 482 and 486.
#
# ##### Differences:
# -  States with a high SAT participation rate tend to have a low ACT participation rate.
# -  The SAT only has 2 test sections, whereas the ACT has 4.
# -  The total score for the SAT is calculated by taking the sum of its section scores. The composite(total) score for the ACT is calculated by taking the mean of its section scores.

# %%
sat_2017.all()
# Out:
# State                                 True
# Participation                         True
# Evidence-Based Reading and Writing    True
# Math                                  True
# Total                                 True
# dtype: bool

# %%
sat_2017.isna().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
act_2017.all()
# Out:
# State            True
# Participation    True
# English          True
# Math             True
# Reading          True
# Science          True
# Composite        True
# dtype: bool

# %%
act_2017.isna().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# The data looks complete, with no null objects in either datasets.

# %% [markdown]
# |   ||SAT|   |ACT|
# |---|---|---|---|---|
# |   |Section|Total|Section|Total|
# |Minimum|200|400|1|36|
# |Maximum|800|1600|1|36|
#
# Sources:
# -  [SAT - PrepScholar](https://blog.prepscholar.com/how-is-the-sat-scored-scoring-charts)
# -  [ACT - PrepScholar](https://blog.prepscholar.com/how-is-the-act-scored)

# %%
sat_2017.describe().T
# Out:
#                                     count         mean        std    min  \
# Evidence-Based Reading and Writing   51.0   569.117647  45.666901  482.0
# Math                                 51.0   547.627451  84.909119   52.0
# Total                                51.0  1126.098039  92.494812  950.0
#
#                                        25%     50%     75%     max
# Evidence-Based Reading and Writing   533.5   559.0   613.0   644.0
# Math                                 522.0   548.0   599.0   651.0
# Total                               1055.5  1107.0  1212.0  1295.0

# %% [markdown]
# An overview of all the numeric features in `sat_2017`, shows a minimum value of `52.0` for Math. This may be an error since the quartiles and maximum value is very similar to that of Evidence-Based Reading and Writing. We also noted earlier that the difference between section scores is minimal.

# %%
sat_2017[(sat_2017.Math == sat_2017.Math.min())]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %% [markdown]
# In order to find the state in which this error may have occurred, we mask `sat_2017` with the minimum value of Math.

# %%
sat_2017.at[20, 'Math'] = 524

# %% [markdown]
# When comparing Maryland's average Math score of `52` to our source, we see an error. We locate the incorrect value and reassign it to the correct value of `524`.

# %%
sat_2017.iloc[[20]]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %% [markdown]
# To confirm our error is fixed, we index into `sat_2017` and look at Maryland's average Math score.

# %%
act_2017.describe().T
# Out:
#          count       mean       std   min     25%    50%     75%   max
# English   52.0  20.919231  2.332132  16.3  19.000  20.55  23.300  25.5
# Math      52.0  21.173077  1.963602  18.0  19.400  20.90  23.100  25.3
# Reading   52.0  22.001923  2.048672  18.1  20.475  21.70  24.125  26.0
# Science   52.0  21.040385  3.151113   2.3  19.900  21.15  22.525  24.9

# %% [markdown]
# An overview of all the numeric features in `act_2017`, shows a minimum value of `2.3` for Science. This may be an error since the quartiles and maximum value is very similar to that of other sections. The minimum value for all other sections are comparable to each other as well.

# %%
act_2017[(act_2017.Science == act_2017.Science.min())]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %% [markdown]
# In order to find the state in which this error may have occurred, we mask `act_2017` with the minimum value of Science.

# %%
act_2017.at[21, 'Science'] = 23.2

# %% [markdown]
# When comparing Maryland's average Science score of `2.3` to our source, we see an error. We locate the incorrect value and reassign it to the correct value of `23.2`.

# %%
act_2017.iloc[[21]]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.2      23.6

# %% [markdown]
# To confirm our error is fixed, we index into `act_2017` and look at Maryland's average Science score.

# %% [markdown]
# We'll explore the data types of each feature.

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# The data type for Evidence-Based Reading and Writing, Math and Total is integer. This is expected as the values are numeric. Participation, however, is an object type. This means the values are stored as strings rather than integers or floats. This needs to be re-typed in order to reflect its numeric feature.

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %% [markdown]
# The data type for English, Math, Reading and Science is integer. This is expected as the values are numeric. Composite, however, is typed as an object. Given that it shares the same traits as each section, Composite is not as it should be. Similar to `sat_2017`, Participation is also incorrectly typed here as an object.

# %% [markdown]
# We will define a function that will allow us to convert participation rates to an appropriate numeric type in order to fix incorrect data types.

# %%
sat_2017['Participation'] = sat_2017['Participation'].apply(lambda _ : float(_.strip('%')))

# %%
act_2017['Participation'] = act_2017['Participation'].apply(lambda _ : float(_.strip('%')))

# %% [markdown]
# In order to re-type Participation in each dataframe, we need to:
#     1. Remove %
#     2. Re-type the string as a float
#     3. Apply this change to our Participation column
#     4. Replace our current Participation column by assigning our float column to it

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
act_2017[['Composite']].tail()
# Out:
#    Composite
# 47      23.8
# 48      21.9
# 49      20.4
# 50      20.5
# 51     20.2x

# %%
act_2017.at[51, 'Composite'] = 20.2

# %% [markdown]
# Upon taking a closer at the Composite column, we see that row 51 is currently displaying `20.2x`. In order to remove `x`, we locate the value and assign `20.2` to it. Now we can re-type the Composite column as a float and assign it back to our current column.

# %% [markdown]
# - Finish our data modifications by making sure the columns are now typed appropriately.

# %%
act_2017['Composite'] = act_2017['Composite'].astype(float)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# Change the names of the columns to more expressive names so that we can tell the difference the SAT columns and the ACT columns.

# %%
sat_2017.columns.tolist()
# Out:
# ['State',
#  'Participation',
#  'Evidence-Based Reading and Writing',
#  'Math',
#  'Total']

# %%
sat_column_dict = {
    'State' : 'state',
    'Participation': 'sat_2017_part',
    'Evidence-Based Reading and Writing' : 'sat_2017_ebrw',
    'Math': 'sat_2017_math',
    'Total' : 'sat_2017_total'
    
}

sat_2017.rename(columns = sat_column_dict, inplace=True)

# %%
sat_2017.columns.tolist()
# Out:
# ['state', 'sat_2017_part', 'sat_2017_ebrw', 'sat_2017_math', 'sat_2017_total']

# %%
act_2017.columns.tolist()
# Out:
# ['State',
#  'Participation',
#  'English',
#  'Math',
#  'Reading',
#  'Science',
#  'Composite']

# %%
act_column_dict = {
    'State' : 'state',
    'Participation' : 'act_2017_part',
    'English' : 'act_2017_eng',
    'Math' : 'act_2017_math',
    'Reading' : 'act_2017_read',
    'Science' : 'act_2017_science',
    'Composite' : 'act_2017_composite'
}

act_2017.rename(columns=act_column_dict, inplace=True)

# %%
act_2017.columns.tolist()
# Out:
# ['state',
#  'act_2017_part',
#  'act_2017_eng',
#  'act_2017_math',
#  'act_2017_read',
#  'act_2017_science',
#  'act_2017_composite']

# %% [markdown]
# #### Create a data dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/SAT|State name|
# |sat_2017_part|float|SAT|The percent of the state high school population that took the SAT in 2017 (units percent to one decimal place, where 5.0 means 5.0%)|
# |sat_2017_ebrw|integer|SAT|The average score of Evidence-Based Reading and Writing section on the SAT for the state in 2017 (200 min. and 800 max.)|
# |sat_2017_math|integer|SAT|The average score of Math section on the SAT for the state in 2017 (200 min. and 800 max.)|
# |sat_2017_total|integer|SAT|The average total score on the SAT for the state in 2017 (sum of Evidence-Based Reading and Writing and Math section)|
# |act_2017_part|float|ACT|The percent of the state high school population that took the ACT in 2017 (units percent to one decimal place, where 65.0 means 65.0%|
# |act_2017_eng|float|ACT|The average score of English section on the ACT for the state in 2017 (1 min. and 36 max.)|
# |act_2017_math|float|ACT|The average score of Math section on the ACT for the state in 2017 (1 min. and 36 max.)|
# |act_2017_read|float|ACT|The average score of Reading section on the ACT for the state in 2017 (1 min. and 36 max.)|
# |act_2017_science|float|ACT|The average score of Science section on the ACT for the state in 2017 (1 min. and 36 max.)|
# |act_2017_composite|float|ACT|The average total score on the ACT for the state in 2017 (average of English, Math, Reading and Science section)|

# %% [markdown]
# #### Drop unnecessary rows

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
act_2017.shape
# Out:
# (52, 7)

# %%
act_2017.head()
# Out:
#       state  act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# 0  National           60.0          20.3           20.7           21.4
# 1   Alabama          100.0          18.9           18.4           19.7
# 2    Alaska           65.0          18.7           19.8           20.4
# 3   Arizona           62.0          18.6           19.8           20.1
# 4  Arkansas          100.0          18.9           19.0           19.7
#
#    act_2017_science  act_2017_composite
# 0              21.0                21.0
# 1              19.4                19.2
# 2              19.9                19.8
# 3              19.8                19.7
# 4              19.5                19.4

# %%
act_2017 = act_2017.drop(labels=0)

# %%
act_2017.reset_index(drop=True, inplace=True)

# %%
act_2017.shape
# Out:
# (51, 7)

# %% [markdown]
# #### Merge Dataframes

# %%
combined_2017 = sat_2017.merge(act_2017, on='state')

# %% [markdown]
# #### Save cleaned, merged dataframe

# %%
combined_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# We'll repeat the same process for our 2018 data.
#
# Read in the `sat_2018.csv` and `act_2018.csv` files and assign them to appropriately named pandas dataframes.

# %%
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')

# %%
sat_2018.sort_values('State').head(10)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 15               Alabama            6%                                 595
# 22                Alaska           43%                                 562
# 16               Arizona           29%                                 577
# 14              Arkansas            5%                                 592
# 31            California           60%                                 540
# 40              Colorado          100%                                 519
# 38           Connecticut          100%                                 535
# 49              Delaware          100%                                 505
# 50  District of Columbia           92%                                 497
# 23               Florida           56%                                 550
#
#     Math  Total
# 15   571   1166
# 22   544   1106
# 16   572   1149
# 14   576   1169
# 31   536   1076
# 40   506   1025
# 38   519   1053
# ...

# %%
act_2018.sort_values('State').head(10)
# Out:
#           State Participation  Composite
# 46      Alabama          100%       19.1
# 26       Alaska           33%       20.8
# 44      Arizona           66%       19.2
# 41     Arkansas          100%       19.4
# 15   California           27%       22.7
# 8      Colorado           30%       23.9
# 0   Connecticut           26%       25.6
# 11     Delaware           17%       23.8
# 39      Florida           66%       19.9
# 23      Georgia           53%       21.4

# %% [markdown]
# #### SAT 2018 Data
# The `sat_2018` dataset consists of 5 columns:
#     1. State
#     2. Participation Rate
#     3. Average Evidence-Based Reading and Writing Score
#     4. Average Math Score
#     5. Average Total Score
#
# ##### Takeaways
# -  We see the same patterns as we did in the `sat_2017` dataset
# -  Participation rate varies drastically per state.
#     -  District of Columbia's participation rate dropped from 100% to 92%.
#     -  Florida's participation rate dropped from 83% to 56%.
#     -  Colorado's participation rate increased from 11% to 100%.
# -  The average score per state for each section ranges from 400-600.
# -  The difference between section scores is minimal.
# -  States with higher participation rates have lower scores when compared to states with lower participation rates.
#    -  With a decrease in Florida's participation rate, the average section and total scores have increased since 2017.
# -  The total is measured by taking the sum of the two sections.

# %% [markdown]
# #### ACT 2018 Data
# The `act_2017` dataframe consists of 3 columns:
#     1. State
#     2. Participation Rate
#     3. Average Composite(Total) Score
# -  We do not have data for average section score per state
#
# ##### Takeaways
# -  We see the same patterns as observed in `act_2017`
# -  Participation rate varies drastically per state.
#     -  Colorado's participation dropped from 100% to only 30%.
# -  States with higher participation rates have lower scores when compared to states with lower participation rates.
#     -  With a decrease in Colorado's participation rate, average composite score has increased from 20.8 to 23.9.
# -  The national participation rate decreased from 60% to 55%.

# %% [markdown]
# #### SAT 2018 vs. ACT 2018
#
# -  States that saw a decrease in SAT participation rate from 2017 saw an increase in ACT participation rate and vice versa.
# -  A significant increase or decrease in participation rates between 2017-2018 may be due to changes in high school graduation requirements.
#     -  Colorado's SAT participation rate in 2018 is 100% due to a change in policies. High schoolers will be required to take the SAT, instead of ACT. [Source: Chalkbeat](https://chalkbeat.org/posts/co/2015/12/23/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers/)
#     -  Similarily, Illinois recently signed a contract with College Board, the administrator of the SAT. This resulted in an increase from 9% to 99% in SAT participation in 2018. [Source: Chicago Tribune](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)

# %%
sat_2018.all()
# Out:
# State                                 True
# Participation                         True
# Evidence-Based Reading and Writing    True
# Math                                  True
# Total                                 True
# dtype: bool

# %%
sat_2018.isna().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
act_2018.all()
# Out:
# State            True
# Participation    True
# Composite        True
# dtype: bool

# %%
act_2018.isna().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %% [markdown]
# The data looks complete, with no null objects in either dataset.

# %%
sat_2018.describe().T
# Out:
#                                     count         mean        std    min  \
# Evidence-Based Reading and Writing   51.0   563.686275  47.502627  480.0
# Math                                 51.0   556.235294  47.772623  480.0
# Total                                51.0  1120.019608  94.155083  977.0
#
#                                        25%     50%     75%     max
# Evidence-Based Reading and Writing   534.5   552.0   610.5   643.0
# Math                                 522.5   544.0   593.5   655.0
# Total                               1057.5  1098.0  1204.0  1298.0

# %%
act_2018.describe().T
# Out:
#            count       mean       std   min     25%    50%     75%   max
# Composite   52.0  21.484615  2.099055  17.7  19.975  21.05  23.625  25.6

# %% [markdown]
# The count for `sat_2018` and `act_2018` is not the same. This must be fixed before merging to avoid any needed rows being dropped.

# %%
sat_2018.State.isin(act_2018.State);

# %%
sat_2018.loc[[10, 37, 50]]
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 10        Missississippi            3%                                 630
# 37             Oaklahoma            8%                                 541
# 50  District of Columbia           92%                                 497
#
#     Math  Total
# 10   606   1236
# 37   521   1062
# 50   480    977

# %%
sat_2018.at[10, 'State'] = 'Mississippi'

# %%
sat_2018.at[37, 'State'] = 'Oklahoma'

# %%
act_2018.State.isin(sat_2018.State);

# %%
act_2018.loc[[13, 27]]
# Out:
#                State Participation  Composite
# 13  Washington, D.C.           32%       23.6
# 27          National           55%       20.8

# %%
act_2018.at[13, 'State'] = 'District of Columbia'

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State            52 non-null object
# Participation    52 non-null object
# Composite        52 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# Similar to the 2017 datasets, the Participation feature is numeric and should be either typed as an integer or float. Here, it is typed as an object for both `sat_2018` and `act_2018`.

# %% [markdown]
# #### Fix Incorrect Data Types

# %%
sat_2018['Participation'] = sat_2018['Participation'].apply(lambda _ : float(_.strip('%')))

# %%
act_2018['Participation'] = act_2018['Participation'].apply(lambda _ : float(_.strip('%')))

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %% [markdown]
# All other columns are of the appriopriate type.

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State            52 non-null object
# Participation    52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# #### Rename Columns
# Change the names of the columns to more expressive names so that we can tell the difference the SAT columns and the ACT columns.

# %%
sat_2018.columns.tolist()
# Out:
# ['State',
#  'Participation',
#  'Evidence-Based Reading and Writing',
#  'Math',
#  'Total']

# %%
sat_18_column_dict = {
    'State' : 'state',
    'Participation': 'sat_2018_part',
    'Evidence-Based Reading and Writing' : 'sat_2018_ebrw',
    'Math': 'sat_2018_math',
    'Total' : 'sat_2018_total'
    
}

sat_2018.rename(columns = sat_18_column_dict, inplace=True)

# %%
sat_2018.columns.tolist()
# Out:
# ['state', 'sat_2018_part', 'sat_2018_ebrw', 'sat_2018_math', 'sat_2018_total']

# %%
act_2018.columns.tolist()
# Out:
# ['State', 'Participation', 'Composite']

# %%
act_18_column_dict = {
    'State' : 'state',
    'Participation' : 'act_2018_part',
    'Composite' : 'act_2018_composite'
}

act_2018.rename(columns=act_18_column_dict, inplace=True)

# %%
act_2018.columns.tolist()
# Out:
# ['state', 'act_2018_part', 'act_2018_composite']

# %% [markdown]
# #### Create a data dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/SAT|State name|
# |sat_2018_part|float|SAT|The percent of the state high school population that took the SAT in 2018 (units percent to one decimal place, where 5.0 means 5.0%)|
# |sat_2018_ebrw|integer|SAT|The average score of Evidence-Based Reading and Writing section on the SAT for the state in 2018 (200 min. and 800 max.)|
# |sat_2018_math|integer|SAT|The average score of Math section on the SAT for the state in 2018 (200 min. and 800 max.)|
# |sat_2018_total|integer|SAT|The average total score on the SAT for the state in 2018 (sum of Evidence-Based Reading and Writing and Math section)|
# |act_2018_part|float|ACT|The percent of the state high school population that took the ACT in 2018 (units percent to one decimal place, where 65.0 means 65.0%|
# |act_2018_composite|float|ACT|The average total score on the ACT for the state in 2018 (average of four sections)|

# %% [markdown]
# #### Drop unnecessary rows

# %%
act_2018 = act_2018.drop(labels=27)

# %%
sat_2018.shape
# Out:
# (51, 5)

# %%
act_2018.shape
# Out:
# (51, 3)

# %% [markdown]
# #### Merge Dataframes

# %%
combined_2018 = sat_2018.merge(act_2018, on='state')

# %% [markdown]
# #### Save cleaned, merged dataframe

# %%
combined_2018.to_csv('../data/combined_2018.csv')

# %% [markdown]
# #### Combine our 2017 and 2018 data into a single dataframe
# Save the contents of this merged dataframe as `final.csv`.

# %%
final = combined_2017.merge(combined_2018, on='state')

# %%
final.to_csv('../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final.describe().T
# Out:
#                     count         mean        std    min      25%     50%  \
# sat_2017_part        51.0    39.803922  35.276632    2.0     4.00    38.0
# sat_2017_ebrw        51.0   569.117647  45.666901  482.0   533.50   559.0
# sat_2017_math        51.0   556.882353  47.121395  468.0   523.50   548.0
# sat_2017_total       51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# act_2017_part        51.0    65.254902  32.140842    8.0    31.00    69.0
# act_2017_eng         51.0    20.931373   2.353677   16.3    19.00    20.7
# act_2017_math        51.0    21.182353   1.981989   18.0    19.40    20.9
# act_2017_read        51.0    22.013725   2.067271   18.1    20.45    21.8
# act_2017_science     51.0    21.450980   1.739353   18.2    19.95    21.3
# act_2017_composite   51.0    21.519608   2.020695   17.8    19.80    21.4
# sat_2018_part        51.0    45.745098  37.314256    2.0     4.50    52.0
# sat_2018_ebrw        51.0   563.686275  47.502627  480.0   534.50   552.0
# ...

# %% [markdown]
# #### Investigate trends in the data

# %% [markdown]
# ##### SAT 2017 - Lowest Participation Rates

# %%
final[final['sat_2017_part'] == final['sat_2017_part'].min()].T
# Out:
#                       15           24            34
# state               Iowa  Mississippi  North Dakota
# sat_2017_part          2            2             2
# sat_2017_ebrw        641          634           635
# sat_2017_math        635          607           621
# sat_2017_total      1275         1242          1256
# act_2017_part         67          100            98
# act_2017_eng        21.2         18.2            19
# act_2017_math       21.3         18.1          20.4
# act_2017_read       22.6         18.8          20.5
# act_2017_science    22.1         18.8          20.6
# act_2017_composite  21.9         18.6          20.3
# sat_2018_part          3            3             2
# sat_2018_ebrw        634          630           640
# sat_2018_math        631          606           643
# sat_2018_total      1265         1236          1283
# act_2018_part         68          100            98
# act_2018_composite  21.8         18.6          20.3

# %% [markdown]
# -  Iowa, Mississippi and North Dakota all have the lowest 2017 SAT Participation rate of `2%`
# -  We can see that their 2017 section and total average scores are much higher when compared to states with higher participation rates.

# %% [markdown]
# ##### SAT 2017 - Highest Participation Rates

# %%
final[final['sat_2017_part'] == final['sat_2017_part'].max()].T
# Out:
#                              6         7                     8         22
# state               Connecticut  Delaware  District of Columbia  Michigan
# sat_2017_part               100       100                   100       100
# sat_2017_ebrw               530       503                   482       509
# sat_2017_math               512       492                   468       495
# sat_2017_total             1041       996                   950      1005
# act_2017_part                31        18                    32        29
# act_2017_eng               25.5      24.1                  24.4      24.1
# act_2017_math              24.6      23.4                  23.5      23.7
# act_2017_read              25.6      24.8                  24.9      24.5
# act_2017_science           24.6      23.6                  23.5      23.8
# act_2017_composite         25.2      24.1                  24.2      24.1
# sat_2018_part               100       100                    92       100
# ...

# %% [markdown]
# -  Connecticut, Delaware, District of Columbia and Michigan all have the highest 2017 SAT Participation rate of `100%`.
# -  When compared to the states with the lowest participation rate, they have lower section and total average scores.

# %% [markdown]
# ##### SAT 2018 - Lowest Participation Rates

# %%
final[final['sat_2018_part'] == final['sat_2018_part'].min()].T
# Out:
#                               34
# state               North Dakota
# sat_2017_part                  2
# sat_2017_ebrw                635
# sat_2017_math                621
# sat_2017_total              1256
# act_2017_part                 98
# act_2017_eng                  19
# act_2017_math               20.4
# act_2017_read               20.5
# act_2017_science            20.6
# act_2017_composite          20.3
# sat_2018_part                  2
# sat_2018_ebrw                640
# sat_2018_math                643
# sat_2018_total              1283
# act_2018_part                 98
# act_2018_composite          20.3

# %% [markdown]
# -  North Dakota has the lowest 2018 SAT participation rate of `2%`.
#     -  This remained the same from 2017.
# -  Iowa and Mississippi's SAT participation rate increased to `3%` from 2017.

# %% [markdown]
# ##### SAT 2018 - Highest Participation Rates

# %%
final[final['sat_2018_part'] == final['sat_2018_part'].max()].T
# Out:
#                           5            6         7      12        22
# state               Colorado  Connecticut  Delaware  Idaho  Michigan
# sat_2017_part             11          100       100     93       100
# sat_2017_ebrw            606          530       503    513       509
# sat_2017_math            595          512       492    493       495
# sat_2017_total          1201         1041       996   1005      1005
# act_2017_part            100           31        18     38        29
# act_2017_eng            20.1         25.5      24.1   21.9      24.1
# act_2017_math           20.3         24.6      23.4   21.8      23.7
# act_2017_read           21.2         25.6      24.8     23      24.5
# act_2017_science        20.9         24.6      23.6   22.1      23.8
# act_2017_composite      20.8         25.2      24.1   22.3      24.1
# sat_2018_part            100          100       100    100       100
# sat_2018_ebrw            519          535       505    508       511
# ...

# %% [markdown]
# -  Colorado, Connecticut, Delaware, Idaho and Michigan all have the higest 2018 SAT Participation rate of `100%`.
# -  There was no change in Participation rate for Connecticut, Delaware and Michigan between 2017-2018.
# -  Idaho's 2018 SAT Participation rate increased from `93%` in 2017.
# -  **Colorado** had the most drastic change in SAT Participation rate, **increasing from `11%` to `100%`**.

# %% [markdown]
# ##### ACT 2017 - Lowest Participation Rates

# %%
final[final['act_2017_part'] == final['act_2017_part'].min()].T
# Out:
#                        19
# state               Maine
# sat_2017_part          95
# sat_2017_ebrw         513
# sat_2017_math         499
# sat_2017_total       1012
# act_2017_part           8
# act_2017_eng         24.2
# act_2017_math          24
# act_2017_read        24.8
# act_2017_science     23.7
# act_2017_composite   24.3
# sat_2018_part          99
# sat_2018_ebrw         512
# sat_2018_math         501
# sat_2018_total       1013
# act_2018_part           7
# act_2018_composite     24

# %% [markdown]
# -  Maine has the lowest 2017 ACT Participation rate of `8%`.
# -  Seeing their 2017 SAT Participation rate at `95%`, we know that high schoolers primarily took the SAT.

# %% [markdown]
# ##### ACT 2017 - Highest Participation Rates

# %%
final[final['act_2017_part'] == final['act_2017_part'].max()].T
# Out:
#                          0         3         5         17         18  \
# state               Alabama  Arkansas  Colorado  Kentucky  Louisiana
# sat_2017_part             5         3        11         4          4
# sat_2017_ebrw           593       614       606       631        611
# sat_2017_math           572       594       595       616        586
# sat_2017_total         1165      1208      1201      1247       1198
# act_2017_part           100       100       100       100        100
# act_2017_eng           18.9      18.9      20.1      19.6       19.4
# act_2017_math          18.4        19      20.3      19.4       18.8
# act_2017_read          19.7      19.7      21.2      20.5       19.8
# act_2017_science       19.4      19.5      20.9      20.1       19.6
# act_2017_composite     19.2      19.4      20.8        20       19.5
# sat_2018_part             6         5       100         4          4
# sat_2018_ebrw           595       592       519       630        615
# ...

# %% [markdown]
# -  All of the following states have a 2017 ACT Participation rate of `100%`:
#     -  Alabama
#     -  Arkansas
#     -  Colorado
#     -  Kentucky
#     -  Louisiana
#     -  Mississippi
#     -  Missouri
#     -  Montana
#     -  Nevada
#     -  North Carolina
#     -  Oklahoma
#     -  South Carolina
#     -  Tennessee
#     -  Utah
#     -  Wisconsin
#     -  Wyoming
# -  Most of these states have a 2017 SAT participation rate less than `10%`, except for Nevada, North Carolina, and South Carolina.
# -  Despite having `100%` participation in the 2017 ACT, **North Carolina and South Carolina have a 2017 SAT participation rate of `49%` and `50%`**, respectively.
#     -  This is particularly high when compared to the other states with less than `10%` participation in the 2017 SAT.

# %% [markdown]
# ##### ACT 2018 - Lowest Participation Rates

# %%
final[final['act_2018_part'] == final['act_2018_part'].min()].T
# Out:
#                        19
# state               Maine
# sat_2017_part          95
# sat_2017_ebrw         513
# sat_2017_math         499
# sat_2017_total       1012
# act_2017_part           8
# act_2017_eng         24.2
# act_2017_math          24
# act_2017_read        24.8
# act_2017_science     23.7
# act_2017_composite   24.3
# sat_2018_part          99
# sat_2018_ebrw         512
# sat_2018_math         501
# sat_2018_total       1013
# act_2018_part           7
# act_2018_composite     24

# %% [markdown]
# -  Maine has the lowest 2018 ACT participation rate of `7%`.
# -  The participation rate decreased from `8%` in 2017.
# -  The SAT participation rate increased from `95%` to `99%`.

# %% [markdown]
# ##### ACT 2018 - Highest Participation Rates

# %%
final[final['act_2018_part'] == final['act_2018_part'].max()].T
# Out:
#                          0         3         17         18           24  \
# state               Alabama  Arkansas  Kentucky  Louisiana  Mississippi
# sat_2017_part             5         3         4          4            2
# sat_2017_ebrw           593       614       631        611          634
# sat_2017_math           572       594       616        586          607
# sat_2017_total         1165      1208      1247       1198         1242
# act_2017_part           100       100       100        100          100
# act_2017_eng           18.9      18.9      19.6       19.4         18.2
# act_2017_math          18.4        19      19.4       18.8         18.1
# act_2017_read          19.7      19.7      20.5       19.8         18.8
# act_2017_science       19.4      19.5      20.1       19.6         18.8
# act_2017_composite     19.2      19.4        20       19.5         18.6
# sat_2018_part             6         5         4          4            3
# ...

# %% [markdown]
# -  Most of the states with a `100%` ACT participation rate in 2017 remained the same in 2018.
# -  One notable absence is Colorado. We noticed before that Colorado's SAT participation rate increased to `100%` in 2018. This can account for Colorado's absence in this table.
# -  Nebraska and Ohio did not previously have `100%` participation rate for the ACT in 2017
#     -  Nebraska had `84%` and Ohio had `75%` participation rate for the 2017 ACT.
#     -  Both states did not see any major changes in SAT participation between the two years.

# %% [markdown]
# ##### SAT 2017 Highest Total Scores

# %%
final.sort_values('sat_2017_total', ascending=False).head().T
# Out:
#                            23         49    15        25      16
# state               Minnesota  Wisconsin  Iowa  Missouri  Kansas
# sat_2017_part               3          3     2         3       4
# sat_2017_ebrw             644        642   641       640     632
# sat_2017_math             651        649   635       631     628
# sat_2017_total           1295       1291  1275      1271    1260
# act_2017_part             100        100    67       100      73
# act_2017_eng             20.4       19.7  21.2      19.8    21.1
# act_2017_math            21.5       20.4  21.3      19.9    21.3
# act_2017_read            21.8       20.6  22.6      20.8    22.3
# act_2017_science         21.6       20.9  22.1      20.5    21.7
# act_2017_composite       21.5       20.5  21.9      20.4    21.7
# sat_2018_part               4          3     3         4       4
# sat_2018_ebrw             643        641   634       633     633
# ...

# %% [markdown]
# -  Minnesota had the highest 2017 SAT total score of `1295`.
# -  All states with a total score of at least `1260` had participation rates less than `5%`.

# %% [markdown]
# ##### SAT 2017 Lowest Total Scores

# %%
final.sort_values('sat_2017_total', ascending=True).head().T
# Out:
#                                       8         7      12        22     19
# state               District of Columbia  Delaware  Idaho  Michigan  Maine
# sat_2017_part                        100       100     93       100     95
# sat_2017_ebrw                        482       503    513       509    513
# sat_2017_math                        468       492    493       495    499
# sat_2017_total                       950       996   1005      1005   1012
# act_2017_part                         32        18     38        29      8
# act_2017_eng                        24.4      24.1   21.9      24.1   24.2
# act_2017_math                       23.5      23.4   21.8      23.7     24
# act_2017_read                       24.9      24.8     23      24.5   24.8
# act_2017_science                    23.5      23.6   22.1      23.8   23.7
# act_2017_composite                  24.2      24.1   22.3      24.1   24.3
# ...

# %% [markdown]
# -  District of Columbia has the lowest 2017 SAT total score of `950`.
# -  The five states with the lowest total scores have participation rates of at least `95%`.
#     -  District of Columbia, Delaware and Michigan all have particiaption rates of `100%`.

# %% [markdown]
# ##### SAT 2018 Highest Total Scores

# %%
final.sort_values('sat_2018_total', ascending=False).head().T
# Out:
#                            23         49            34    15      16
# state               Minnesota  Wisconsin  North Dakota  Iowa  Kansas
# sat_2017_part               3          3             2     2       4
# sat_2017_ebrw             644        642           635   641     632
# sat_2017_math             651        649           621   635     628
# sat_2017_total           1295       1291          1256  1275    1260
# act_2017_part             100        100            98    67      73
# act_2017_eng             20.4       19.7            19  21.2    21.1
# act_2017_math            21.5       20.4          20.4  21.3    21.3
# act_2017_read            21.8       20.6          20.5  22.6    22.3
# act_2017_science         21.6       20.9          20.6  22.1    21.7
# act_2017_composite       21.5       20.5          20.3  21.9    21.7
# sat_2018_part               4          3             2     3       4
# sat_2018_ebrw             643        641           640   634     633
# ...

# %% [markdown]
# -  Minnesota has the highest 2018 SAT total score of `1298`.
#     -  The score is a very small increase from `1295` in 2017.
#     -  The 2018 SAT participation rate remains low at `4%`.
# -  Similar to the SAT 2017 highest total scores, the states with high scores have low participation rates.

# %% [markdown]
# ##### SAT 2018 Lowest Total Scores

# %%
final.sort_values('sat_2018_total', ascending=True).head().T
# Out:
#                                       8         7              48     12    44
# state               District of Columbia  Delaware  West Virginia  Idaho  Utah
# sat_2017_part                        100       100             14     93     3
# sat_2017_ebrw                        482       503            558    513   624
# sat_2017_math                        468       492            528    493   614
# sat_2017_total                       950       996           1086   1005  1238
# act_2017_part                         32        18             69     38   100
# act_2017_eng                        24.4      24.1             20   21.9  19.5
# act_2017_math                       23.5      23.4           19.4   21.8  19.9
# act_2017_read                       24.9      24.8           21.2     23  20.8
# act_2017_science                    23.5      23.6           20.5   22.1  20.6
# act_2017_composite                  24.2      24.1           20.4   22.3  20.3
# ...

# %% [markdown]
# -  District of Columbia has the 2018 SAT lowest total score of `977`.
#     -  This rank remained the same as 2017.

# %% [markdown]
# ##### ACT 2017 Highest Composite(Total) Scores

# %%
final.sort_values('act_2017_composite', ascending=False).head().T
# Out:
#                                29             21           6      19  \
# state               New Hampshire  Massachusetts  Connecticut  Maine
# sat_2017_part                  96             76          100     95
# sat_2017_ebrw                 532            555          530    513
# sat_2017_math                 520            551          512    499
# sat_2017_total               1052           1107         1041   1012
# act_2017_part                  18             29           31      8
# act_2017_eng                 25.4           25.4         25.5   24.2
# act_2017_math                25.1           25.3         24.6     24
# act_2017_read                  26           25.9         25.6   24.8
# act_2017_science             24.9           24.7         24.6   23.7
# act_2017_composite           25.5           25.4         25.2   24.3
# sat_2018_part                  96             80          100     99
# sat_2018_ebrw                 535            562          535    512
# ...

# %% [markdown]
# -  New Hampshire has the 2017 ACT highest composite score of `25.5`.
#     -  Participation rate is relatively low at `18%`.

# %% [markdown]
# ##### ACT 2017 Lowest Composite(Total) Scores

# %%
final.sort_values('act_2017_composite', ascending=True).head().T
# Out:
#                         28           24              40      11  \
# state               Nevada  Mississippi  South Carolina  Hawaii
# sat_2017_part           26            2              50      55
# sat_2017_ebrw          563          634             543     544
# sat_2017_math          553          607             521     541
# sat_2017_total        1116         1242            1064    1085
# act_2017_part          100          100             100      90
# act_2017_eng          16.3         18.2            17.5    17.8
# act_2017_math           18         18.1            18.6    19.2
# act_2017_read         18.1         18.8            19.1    19.2
# act_2017_science      18.2         18.8            18.9    19.3
# act_2017_composite    17.8         18.6            18.7      19
# sat_2018_part           23            3              55      56
# sat_2018_ebrw          574          630             547     480
# sat_2018_math          566          606             523     530
# ...

# %% [markdown]
# -  Nevada has the 2017 ACT lowest composite score of `17.8`.
#     - Participation rate is at `100%`.
# -  Other states with low scores also have high participation rates of at least `90%`.

# %% [markdown]
# ##### ACT 2018 Highest Composite(Total) Scores

# %%
final.sort_values('act_2018_composite', ascending=False).head().T
# Out:
#                              6              21             29        32  \
# state               Connecticut  Massachusetts  New Hampshire  New York
# sat_2017_part               100             76             96        67
# sat_2017_ebrw               530            555            532       528
# sat_2017_math               512            551            520       523
# sat_2017_total             1041           1107           1052      1052
# act_2017_part                31             29             18        31
# act_2017_eng               25.5           25.4           25.4      23.8
# act_2017_math              24.6           25.3           25.1        24
# act_2017_read              25.6           25.9             26      24.6
# act_2017_science           24.6           24.7           24.9      23.9
# act_2017_composite         25.2           25.4           25.5      24.2
# sat_2018_part               100             80             96        79
# ...

# %% [markdown]
# -  Connecticut has the 2018 ACT highest composite score of `25.6`.
# -  The states with high ACT composite scores in 2017 also had high ACT composite scores in 2018.
# -  The participation rate remains low for these states.

# %% [markdown]
# ##### ACT 2018 Lowest Composite(Total) Scores

# %%
final.sort_values('act_2018_composite', ascending=True).head().T
# Out:
#                         28              40           24      11       0
# state               Nevada  South Carolina  Mississippi  Hawaii  Alabama
# sat_2017_part           26              50            2      55        5
# sat_2017_ebrw          563             543          634     544      593
# sat_2017_math          553             521          607     541      572
# sat_2017_total        1116            1064         1242    1085     1165
# act_2017_part          100             100          100      90      100
# act_2017_eng          16.3            17.5         18.2    17.8     18.9
# act_2017_math           18            18.6         18.1    19.2     18.4
# act_2017_read         18.1            19.1         18.8    19.2     19.7
# act_2017_science      18.2            18.9         18.8    19.3     19.4
# act_2017_composite    17.8            18.7         18.6      19     19.2
# sat_2018_part           23              55            3      56        6
# ...

# %% [markdown]
# -  Nevada has the 2018 lowest composite score of `17.7`.
#     -  There is minimal change in the composite score compared to 2017.
#     -  Participation rate remains at `100%`.
# -  Of the 5 states with the 2017 lowest composite scores, 4 remain to be the case in 2018.

# %% [markdown]
# ##### SAT 100% Participation

# %%
sat_full_part = (final['sat_2017_part'] == 100.0) | (final['sat_2018_part'] == 100.0)
final[sat_full_part].loc[: , ['state', 'sat_2017_part', 'sat_2018_part']].sort_values(['sat_2017_part', 'sat_2018_part']).head(3)
# Out:
#                    state  sat_2017_part  sat_2018_part
# 5               Colorado           11.0          100.0
# 12                 Idaho           93.0          100.0
# 8   District of Columbia          100.0           92.0

# %% [markdown]
# -  Colorado's SAT participation rate increased from `11%` to `100%`.
# -  Idaho and Distrit of Columbia saw changes in their SAT participation rates between 2017-2018, but not as significant when compared to Colorado.

# %% [markdown]
# ##### ACT 100% Participation

# %%
act_full_part = (final['act_2017_part'] == 100.0) | (final['act_2018_part'] == 100.0)
final[act_full_part].loc[: , ['state', 'act_2017_part', 'act_2018_part']].sort_values(['act_2017_part', 'act_2018_part']).head(4)
# Out:
#         state  act_2017_part  act_2018_part
# 35       Ohio           75.0          100.0
# 27   Nebraska           84.0          100.0
# 5    Colorado          100.0           30.0
# 23  Minnesota          100.0           99.0

# %% [markdown]
# -  Ohio and Nebraska both increased to `100%` participation in 2018.
# -  Colorado saw a significant decrease from `100%` in 2017 to only `30%` in 2018.
#     -  Based on the previous table, we can see that there was a significant increase in the SAT participation rate.
# -  Minnesota's participation rate only decreased by `1%` in 2018.

# %% [markdown]
# ##### SAT and ACT Participation > 50%

# %%
final[
    ((final['sat_2017_part'] > 50.0) & (final['act_2017_part'] > 50.0)) | (
        (final['sat_2018_part'] > 50.0) & (final['act_2018_part'] > 50.0))].T
# Out:
#                          9        10      11              33              40
# state               Florida  Georgia  Hawaii  North Carolina  South Carolina
# sat_2017_part            83       61      55              49              50
# sat_2017_ebrw           520      535     544             546             543
# sat_2017_math           497      515     541             535             521
# sat_2017_total         1017     1050    1085            1081            1064
# act_2017_part            73       55      90             100             100
# act_2017_eng             19       21    17.8            17.8            17.5
# act_2017_math          19.4     20.9    19.2            19.3            18.6
# act_2017_read            21       22    19.2            19.6            19.1
# act_2017_science       19.4     21.3    19.3            19.3            18.9
# act_2017_composite     19.8     21.4      19            19.1            18.7
# ...

# %% [markdown]
# -  States with greater than 50% participation on both the SAT and ACT:
#     -  Florida
#     -  Georgia
#     -  Hawaii
#     -  North Carolina
#     -  South Carolina
# -  Hawaii, North Carolina and South Carolina all have ACT participation rates either close to or at `100%`. However, their SAT participation rates remain high at around `50%`.

# %% [markdown]
# #### Interesting States
# -  **Colorado**: Significant increase in SAT participation rate
#     -  2017 SAT participation rate = `11%`
#     -  2018 SAT participation rate = `100%`
# - **North Carolina** and **South Carolina**: SAT participation rate remains high, despite `100%` ACT participation rate
#     -  2017 - 2018 ACT participation rate = `100%`
#     -  2017 - 2018 SAT particpation rate ~ `50%`

# %% [markdown]
# ## Visualize the data

# %%
fig = plt.figure(figsize=(18, 15))
mask = np.triu(np.ones_like(final.corr()))
ax = sns.heatmap(final.corr(), 
                 annot=True, 
                 annot_kws={'size':15}, 
                 mask=mask, 
                 cmap='Blues')
ax.set_title('Correlation between SAT and ACT', fontsize=30)
ax.tick_params(labelsize=15)
y_min, y_max = ax.get_ylim()
x_min, x_max = ax.get_xlim()
ax.set_ylim(top=y_max+1)
ax.set_xlim(right=x_max-1);

# %% [markdown]
# We define a custom function to subplot histograms

# %%
def subplot_histograms(df, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(20, 5*nrows), sharey='all')
    ax = ax.ravel()
    
    if len(list_of_columns) %2 !=0:
        ax[len(list_of_columns)].set_visible(False)
        
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(df[column], bins=15) # feel free to add more settings
        ax[i].set_title(list_of_titles[i], fontsize=20)
        ax[i].set_ylabel('Count of States', fontsize=15)
        ax[i].set_xlabel(list_of_xlabels[i], fontsize=15)

    plt.tight_layout()

# %% [markdown]
# #### Histograms

# %% [markdown]
# ##### Participation Rates for SAT and ACT

# %%
subplot_histograms(final, 
                   list_of_columns=['sat_2017_part', 'sat_2018_part', 'act_2017_part', 'act_2018_part'], 
                   list_of_titles=['2017 SAT Participation', '2018 SAT Participation', '2017 ACT Participation', '2018 ACT Participation'], 
                   list_of_xlabels = ['2017 SAT Participation', '2018 SAT Participation', '2017 ACT Participation', '2018 ACT Participation'])

# %% [markdown]
# -  The mode for SAT participation is close to `0%` in both 2017 and 2018.
# -  Some states increased their SAT participation in 2018, resulting in higher count betwen `60%` - `80%`.
# -  The mode for ACT participation is close to `100%` in both 2017 and 2018.
# -  There are less states with an ACT participation rate between `50%` - `90%` in 2018.

# %% [markdown]
# ##### Math Scores for SAT and ACT

# %%
subplot_histograms(final, 
                   list_of_columns=['sat_2017_math', 'sat_2018_math', 'act_2017_math'], 
                   list_of_titles=['SAT 2017 Math Scores', 'SAT 2018 Math Scores', 'ACT 2017 Math Scores'], 
                   list_of_xlabels = ['SAT Math Score', 'SAT Math Score', 'ACT Math Score'])

# %% [markdown]
# -  The mode for the SAT math score increased from 2017 to 2018.
# -  There appears to be a shift where more states have lower SAT math scores in 2018.
# -  The mode for the ACT math score is around 19 in 2017.
# -  There is no 2018 ACT math score data to compare with previous year.
# -  Depsite having the same y-axis, it's difficult to compare the 2017 SAT and ACT math scores due to the different scoring methods used.

# %% [markdown]
# ##### Reading/Verbal Scores for SAT and ACT

# %%
subplot_histograms(final, 
                   list_of_columns=['sat_2017_ebrw', 'sat_2018_ebrw', 'act_2017_eng', 'act_2017_read'], 
                   list_of_titles=['SAT 2017 Evidence-Based\n Reading and Writing Scores', 
                                   'SAT 2018 Evidence-Based\n Reading and Writing Scores', 
                                   'ACT 2017 English Scores',
                                  'ACT 2017 Reading Scores'], 
                   list_of_xlabels = ['EBRW Score', 'EBRW Score', 'English Score', 'Reading Score'])

# %% [markdown]
# -  The distribution of 2017 and 2018 SAT reading scores are relatively similar.
# -  We see an increase in states scoring above `640`, but we also see a decrease in states scoring at `570`.
# -  The histogram of  2017 ACT english scores is bimodal, with a mode around `21`.
# -  The data in 2017 ACT Reading Scores range from `18` to `26`, so the approximate range is `8`.

# %% [markdown]
# #### Scatter plots

# %% [markdown]
# ##### Relationship between SAT and ACT Scores

# %%
def subplot_scatter(df, x_list, y_list, list_of_titles):
    nrows = int(np.ceil(len(x_list)/2))
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(20, 5*nrows))
    ax = ax.ravel()
    xy_axis = zip(x_list, y_list)
    
    if len(x_list) % 2 !=0:
        ax[len(x_list)].set_visible(False)
    
    for i, values in enumerate(xy_axis):
        x = values[0]
        y = values[1]
        ax[i].scatter(df[x], df[y])
        ax[i].set_title(list_of_titles[i], fontsize=20)
        ax[i].set_ylabel(f'{y}', fontsize=15)
        ax[i].set_xlabel(f'{x}', fontsize=15)
    
    plt.tight_layout()

# %%
subplot_scatter(df=final,
                x_list=['sat_2017_math', 'sat_2017_ebrw', 'sat_2017_total', 'sat_2017_total', 'act_2017_composite'],
                y_list=['act_2017_math', 'act_2017_read', 'act_2017_composite', 'sat_2018_total', 'act_2018_composite'],
                list_of_titles= ['Relationship between 2017 SAT and ACT Math Scores',
                                 'Relationship between 2017 SAT and ACT Reading Scores',
                                 'Relationship between 2017 SAT and ACT Total Scores',
                                 'Relationship between 2017 and 2018 SAT Total Scores',
                                 'Relationship between 2017 and 2018 ACT Composite Scores'],)

# %% [markdown]
# -  There is a weak, negative correlation between 2017 SAT and 2017 ACT math scores.
# -  There is a weak, negative correlation between 2017 SAT Evidence-Based Reading and Writing and 2017 ACT Reading scores.
# -  There is a weak, negative correlation between 2017 SAT and 2017 ACT total scores.
# -  There is a strong, positive correlation between 2017 and 2018 SAT total scores.
# -  There is a strong, positive correlation between 2017 and 2018 ACT composite(total) scores.

# %% [markdown]
# #### Boxplots

# %% [markdown]
# ##### 2017 - 2018 SAT Total Scores

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=[final.sat_2017_total, final.sat_2018_total])
plt.xlabel('Test', fontsize=15)
plt.ylabel('Total Score', fontsize=15)
plt.title('Boxplot of SAT Total Scores', fontsize=20)
plt.xticks([0, 1], ['SAT 2017', 'SAT 2018'], fontsize=15);

# %% [markdown]
# -  Both have a similar median around `1100`.
# -  SAT 2017 has a greater range (max-min) than SAT 2018 does.
# -  SAT 2017 also has a slightly greater interquartile range than SAT 2018 does.

# %% [markdown]
# ##### 2017 - 2018 SAT Section Scores

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=[final.sat_2017_math, final.sat_2018_math, final.sat_2017_ebrw, final.sat_2018_ebrw])
plt.xlabel('SAT Subtests', fontsize=15)
plt.ylabel('Score', fontsize=15)
plt.title('Boxplot of SAT Subtest and Test Scores', fontsize=20)
plt.xticks([0, 1, 2, 3], ['2017 Math', '2018 Math', '2017 EBRW', '2018 EBRW'], fontsize=15);

# %% [markdown]
# -  The median is around 550 for all boxplots.
# -  Both the 2017 and 2018 math scores have a greater range than 2017 and 2018 Evidence-Based Reading and Writing.
# -  There are no outliers for all boxplots.
# -  2018 math scores have the smallest interquartile range.

# %% [markdown]
# ##### 2017 - 2018 SAT and ACT Participation

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=[final.sat_2017_part, final.sat_2018_part, final.act_2017_part, final.act_2018_part])
plt.xlabel('Test', fontsize=15)
plt.ylabel('Participation', fontsize=15)
plt.title('Boxplot of SAT and ACT Participation', fontsize=20)
plt.xticks([0, 1, 2, 3], ['SAT 2017', 'SAT 2018', 'ACT 2017', 'ACT 2018'], fontsize=15);

# %% [markdown]
# -  The SAT participation rates in 2017 and 2018 have the first(25th) quartile close to the minimum of `0`.
# -  SAT 2018 has a greater interquartile range than SAT 2017.
# -  The ACT participation rates in 2017 and 2018 have the third(75th) quartile at the maximum of `100`.

# %% [markdown]
# ##### 2017 ACT Section Scores

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=[final.act_2017_eng, final.act_2017_math, 
               final.act_2017_read, final.act_2017_science, 
               final.act_2017_composite, final.act_2018_composite])
plt.xlabel('ACT Subtests', fontsize=15)
plt.ylabel('Score', fontsize=15)
plt.title('Boxplot of ACT Subtest and Test Scores', fontsize=20)
plt.xticks([0, 1, 2, 3, 4, 5], 
           ['2017 English', '2017 Math', '2017 Reading', '2017 Science', '2017 Composite', '2018 Composite'],
           rotation='vertical',
           fontsize=15);

# %% [markdown]
# -  The english scores have the lowest minimum close to `16`.
# -  The science scores have the lowest interquartile range (smaller spread).
# -  There are no outliers for any boxplot.
# -  The median is around `21` for all boxplots.

# %% [markdown]
# #### Additional Plots

# %% [markdown]
# ##### Scatter Plot - SAT and ACT 2017 Participation Rate

# %%
subplot_scatter(df=final,
                x_list = ['sat_2017_part'],
                y_list = ['act_2017_part'], 
                list_of_titles = ['Relationship between 2017 SAT and ACT Participation'])

# %% [markdown]
# -  There appears to be a negative correlation between SAT and ACT particition.
# -  States that have high participation on one exam tend to have very minimal participation on the another.

# %% [markdown]
# ##### Side by Side Bar Chart - SAT and ACT 2017 Participation per State

# %%
plt.figure(figsize=(30, 10))
plt.bar(x=final['state'],
        height=final['sat_2017_part'],
        align='edge',
        width=-.4)
plt.bar(x=final['state'],
        height=final['act_2017_part'],
        align='edge',
        width=.4)
plt.xlabel('State', fontsize=15)
plt.ylabel('Participation (%)', fontsize=15)
plt.title('SAT vs. ACT Participation in 2017', fontsize=20)
plt.legend(['SAT', 'ACT'], fontsize=15)
plt.xticks(rotation='vertical');

# %% [markdown]
# -  ACT has 100% participation in more states than SAT.
# -  States with high ACT participation (greater than 80%) typically have SAT participation less than 20%.

# %% [markdown]
# ##### Side by Side Bar Chart - SAT and ACT 2018 Participation Rate per State

# %%
plt.figure(figsize=(30, 10))
plt.bar(x=final['state'],
        height=final['sat_2018_part'],
        align='edge',
        width=-.4)
plt.bar(x=final['state'],
        height=final['act_2018_part'],
        align='edge',
        width=.4)
plt.xlabel('State', fontsize=15)
plt.ylabel('Participation (%)', fontsize=15)
plt.title('SAT vs. ACT Participation in 2018', fontsize=20)
plt.legend(['SAT', 'ACT'], fontsize=15)
plt.xticks(rotation='vertical');

# %% [markdown]
# -  ACT continue to have 100% participation in more states than SAT.
# -  We see similar trends between the two exams in both years.

# %% [markdown]
# ##### Side by Side Bar Chart - SAT Participation per State

# %%
plt.figure(figsize=(30, 10))
plt.bar(x=final['state'],
        height=final['sat_2017_part'],
        align='edge',
        width=-.4)
plt.bar(x=final['state'],
        height=final['sat_2018_part'],
        align='edge',
        width=.4)
plt.xlabel('State', fontsize=15)
plt.ylabel('Participation (%)', fontsize=15)
plt.title('SAT Participation Rate by State', fontsize=20)
plt.legend(['2017', '2018'], fontsize=15)
plt.xticks(rotation='vertical');

# %% [markdown]
# -  States with a participation rate of 100% in 2017 retained the same rate in 2018.
# -  Colorado, Illinois and Rhode Island saw the greatest **positive** change between 2017 and 2018.
# -  Florida saw the greatest **negative** percentage change between 2017 and 2018.

# %% [markdown]
# ##### Side by Side Bar Chart - ACT Participation per State

# %%
plt.figure(figsize=(30, 10))
plt.bar(x=final['state'],
        height=final['act_2017_part'],
        align='edge',
        width=-.4)
plt.bar(x=final['state'],
        height=final['act_2018_part'],
        align='edge',
        width=.4)
plt.xlabel('State', fontsize=15)
plt.ylabel('Participation (%)', fontsize=15)
plt.title('ACT Participation Rate by State', fontsize=20)
plt.legend(['2017', '2018'], fontsize=15)
plt.xticks(rotation='vertical');

# %% [markdown]
# -  Colorado and Illionois saw a significant decrease in ACT participation from 2017 to 2018.
#     -  These are the same states that saw the greatest positive change in SAT participation.
# -  The remaining states with 100% ACT participation retained similar rates in 2018.

# %% [markdown]
# #### High Rate Changes by State

# %%
final[(final.sat_2017_part < 50) & (final.sat_2018_part > 90.0)]
# Out:
#        state  sat_2017_part  sat_2017_ebrw  sat_2017_math  sat_2017_total  \
# 5   Colorado           11.0            606            595            1201
# 13  Illinois            9.0            559            556            1115
#
#     act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# 5           100.0          20.1           20.3           21.2
# 13           93.0          21.0           21.2           21.6
#
#     act_2017_science  act_2017_composite  sat_2018_part  sat_2018_ebrw  \
# 5               20.9                20.8          100.0            519
# 13              21.3                21.4           99.0            513
#
#     sat_2018_math  sat_2018_total  act_2018_part  act_2018_composite
# 5             506            1025           30.0                23.9
# 13            506            1019           43.0                23.9

# %%
final[(final.sat_2018_part > 90.0) & (final.sat_2017_part != final.sat_2018_part) & (final.sat_2017_part < final.sat_2018_part)]
# Out:
#            state  sat_2017_part  sat_2017_ebrw  sat_2017_math  sat_2017_total  \
# 5       Colorado           11.0            606            595            1201
# 12         Idaho           93.0            513            493            1005
# 13      Illinois            9.0            559            556            1115
# 19         Maine           95.0            513            499            1012
# 39  Rhode Island           71.0            539            524            1062
#
#     act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# 5           100.0          20.1           20.3           21.2
# 12           38.0          21.9           21.8           23.0
# 13           93.0          21.0           21.2           21.6
# 19            8.0          24.2           24.0           24.8
# 39           21.0          24.0           23.3           24.7
#
#     act_2017_science  act_2017_composite  sat_2018_part  sat_2018_ebrw  \
# ...

# %% [markdown]
# #### Tableau - Choropleth Map

# %% [markdown]
# ![Choropleth Map - 2018 SAT Participation]('../visuals/sat_2018_part.png')

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %%
def subplot_dist(df):
    nrows = int(np.ceil(len(df.select_dtypes(include=('float64', 'int64')).columns)/2)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(20, 5*nrows))
    ax = ax.ravel()
    
    for i, column in enumerate(df.select_dtypes(include=('float64', 'int64')).columns):
        sns.distplot(df[column], kde=True, ax=ax[i], bins=8)
        ax[i].set_title(df.select_dtypes(include=('float64', 'int64')).columns[i], fontsize=20)
        ax[i].set_ylabel(ylabel= df.select_dtypes(include=('float64', 'int64')).columns[i],fontsize=15)
            
    plt.tight_layout()

# %%
subplot_dist(final)
# Out:
# /Users/connie/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# We see a bimodal distribution for all numeric features of the dataset. This can be due to the fact that scores can be divided into two groups:
# 1. Students who were well-prepared and achieved high scores on each section.
# 2. Students who were not prepared, but took either assessment out of necessity.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# ### Colorado

# %%
final.loc[[5]]
# Out:
#       state  sat_2017_part  sat_2017_ebrw  sat_2017_math  sat_2017_total  \
# 5  Colorado           11.0            606            595            1201
#
#    act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# 5          100.0          20.1           20.3           21.2
#
#    act_2017_science  act_2017_composite  sat_2018_part  sat_2018_ebrw  \
# 5              20.9                20.8          100.0            519
#
#    sat_2018_math  sat_2018_total  act_2018_part  act_2018_composite
# 5            506            1025           30.0                23.9

# %% [markdown]
# Colorado had a significant increase in SAT participation rate and decrease in ACT participation rate from 2017-2018. Their SAT participation increased by 89%, whereas their ACT participation decreased by 70%. There's an apparant tradeoff here, with high schoolers forgoing the ACT in favor of the SAT in 2018.
#
# On December 23, 2015, the [Colorado Department of Education](https://www.cde.state.co.us/communications/11thand10thgradeexams) announced that the SAT was to replace the ACT, with the transition to take place in 2017. This aligns with our observed trend of a sudden increase in SAT participation after 2017. The state's selection committee provided the following explanation for the change:
# > The College Board’s reporting system more useful to students, as it connects students to resources and activities designed to help identify next steps for extra support or possible acceleration. [Source: Chalkbeat](https://chalkbeat.org/posts/co/2015/12/23/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers/)
#
# The [Colorado Department of Education](https://www.cde.state.co.us/assessment/coloradosat) further disclosed the advantages of partnering with College Board to administer the SAT:
# -  Free SAT test
#     -  Colorado and the College Board have partnered to provide the SAT for free. Students will not have to pay the fee typically required of other states.
# -  Free SAT practice through Khan Academy
#     -  Students have access to additional study materials, personalized recommendations and practice exams.
# -  Student SAT Reports
#     -  Students are provided with a detailed breakdown of their performance and suggestions for areas of improvement.
#
# The change in participation rate also led to a change in average section and total scores. The SAT average total score decreased from 1201 to 1025, while the ACT average composite score increased from 20.8 to 23.9.

# %%
plt.figure(figsize=(15, 10))
sat_bar_co = plt.bar(['2017', '2018'], [final.at[5, 'sat_2017_part'], final.at[5, 'sat_2018_part']], align='edge', width=-.4)
act_bar_co = plt.bar(['2017', '2018'], [final.at[5, 'act_2017_part'], final.at[5, 'act_2018_part']], align='edge', width=.4)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Participation (%)', fontsize=15)
plt.title('Colorado\'s SAT and ACT Participation Rate', fontsize=20)
plt.legend(['SAT', 'ACT'], fontsize=15)

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        plt.annotate(s='%d' % int(height),
                     xy=(bar.get_x() + bar.get_width()/2, 1.05+height),
                     ha='center',
                     va='bottom',
                     fontsize=15)

autolabel(sat_bar_co)
autolabel(act_bar_co);

# %% [markdown]
# ### Illinois

# %%
final.loc[[13]]
# Out:
#        state  sat_2017_part  sat_2017_ebrw  sat_2017_math  sat_2017_total  \
# 13  Illinois            9.0            559            556            1115
#
#     act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# 13           93.0          21.0           21.2           21.6
#
#     act_2017_science  act_2017_composite  sat_2018_part  sat_2018_ebrw  \
# 13              21.3                21.4           99.0            513
#
#     sat_2018_math  sat_2018_total  act_2018_part  act_2018_composite
# 13            506            1019           43.0                23.9

# %% [markdown]
# Illinois saw a significant increase in SAT participation rate, while the ACT participation rate dropped by 50% from 2017-2018. Similar to Colorada, we're seeing the increased SAT participation rate offsetting the ACT's.
#
# The College Board has partnered with the state of Illinois in a 3 year contract to administer the SAT. Students will have access to free resources from Khan Academy, SAT tests available to be taken during the weekday, and personalized reports.
# [Source: Chicago Tribune](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)
#
# Though we observe a decrease in the ACT participation rate, it did not decreae as significantly as Colorado's. This can be due to districts continuing to offer the ACT free of charge, albeit only temporarily. Many students were prepped for the ACT during their early high school years, not the SAT. Many school districts see it as only reasonable to offer the ACT during this transition.
# [Source: Chicago Tribune](https://www.chicagotribune.com/news/local/breaking/ct-iillinois-act-exam-met-20170414-story.html)
#
# Again, we observe a decrease in SAT average section and total scores with an increase in participation rate.

# %%
plt.figure(figsize=(15, 10))
sat_bar_il = plt.bar(['2017', '2018'], [final.at[13, 'sat_2017_part'], final.at[13, 'sat_2018_part']], align='edge', width=-.4)
act_bar_il = plt.bar(['2017', '2018'], [final.at[13, 'act_2017_part'], final.at[13, 'act_2018_part']], align='edge', width=.4)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Participation (%)', fontsize=15)
plt.title('Illinois\' SAT and ACT Participation Rate', fontsize=20)
plt.legend(['SAT', 'ACT'], fontsize=15)

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        plt.annotate(s='%d' % int(height),
                     xy=(bar.get_x() + bar.get_width()/2, 1.05+height),
                     ha='center',
                     va='bottom',
                     fontsize=15)

autolabel(sat_bar_il)
autolabel(act_bar_il);

# %% [markdown]
# ### Idaho

# %%
final.loc[[12]]
# Out:
#     state  sat_2017_part  sat_2017_ebrw  sat_2017_math  sat_2017_total  \
# 12  Idaho           93.0            513            493            1005
#
#     act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# 12           38.0          21.9           21.8           23.0
#
#     act_2017_science  act_2017_composite  sat_2018_part  sat_2018_ebrw  \
# 12              22.1                22.3          100.0            508
#
#     sat_2018_math  sat_2018_total  act_2018_part  act_2018_composite
# 12            493            1001           36.0                22.3

# %% [markdown]
# Idaho has a SAT participation rate of 100% in 2018, a 7% increase from its previous year. Given the incremental change in participation, a new state policy seems unlikely. The 2017-2018 ACT participation rates are also not as low when compared to other states with a high SAT participation rate.
#
# According to the [Idaho State Department of Education](http://www.sde.idaho.gov/assessment/college/), the state pays for a statewide college entrance exam each year. In 2018, this was the SAT. It's important to note how the state managed to achieve 100% participation in the 2018 SAT when it's not required nor the only option high schoolers have. Both the SAT and ACT meet high school graduation requirements. The 100% participation rate appears to be largely due to the Idaho SAT School Day.
#
# Idaho SAT School Day entices students to take the SAT because:
# -  All public school students are exempt from the exame fee.
# -  The SAT is offered on a school day, making it more convenient than taking the exam over the weekend.
#
# [Source: CollegeBoard](https://collegereadiness.collegeboard.org/sat/k12-educators/sat-school-day/about) <br>
# [Source: Next Steps](https://nextsteps.idaho.gov/resources/act-vs-sat/)

# %%
plt.figure(figsize=(15, 10))
sat_bar_id = plt.bar(['2017', '2018'], [final.at[12, 'sat_2017_part'], final.at[12, 'sat_2018_part']], align='edge', width=-.4)
act_bar_id = plt.bar(['2017', '2018'], [final.at[12, 'act_2017_part'], final.at[12, 'act_2018_part']], align='edge', width=.4)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Participation (%)', fontsize=15)
plt.title('Idaho\'s SAT and ACT Participation Rate', fontsize=20)
plt.legend(['SAT', 'ACT'], fontsize=15)

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        plt.annotate(s='%d' % int(height),
                     xy=(bar.get_x() + bar.get_width()/2, 1.05+height),
                     ha='center',
                     va='bottom',
                     fontsize=15)

autolabel(sat_bar_id)
autolabel(act_bar_id);

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# **Secure statewide testing contracts**: The dramatic increase in SAT participation for Colorado and Illinois within the span of two years demonstrates the importance of establishing state partnerships. Executing a contract leads to immediate results.
#
# **Implement SAT School Day**: Though securing testing contracts proves to be the most direct method in increasing participation rates, it may not be the easiest nor fastest to attain. As an alternative, the College Board can choose to implement SAT School Day within more school districts. Idaho’s 100% participation rate in 2018 justifies the value of having such an event, especially for states that already have moderate to high SAT participation. Given the choice, students will prefer the convenience and accessibility provided by SAT School Day over the ACT.
#
# **Target relevant states**: The ideal outcome is to increase SAT participation rate in all states, but it’s not practical to target all of them. To properly allocate our resources, do not target states that are still contractually bound to ACT. Rather, direct efforts towards states that already show a propensity for the SAT or at least those that do not have a strong preference for either. Presenting the SAT and its free resources will more likely incline these states to make a temporary, if not permanent, change. California is a desirable target because participation is fairly distributed between the SAT and ACT.

# %% [markdown]
# ### California

# %%
final.loc[[4]]
# Out:
#         state  sat_2017_part  sat_2017_ebrw  sat_2017_math  sat_2017_total  \
# 4  California           53.0            531            524            1055
#
#    act_2017_part  act_2017_eng  act_2017_math  act_2017_read  \
# 4           31.0          22.5           22.7           23.1
#
#    act_2017_science  act_2017_composite  sat_2018_part  sat_2018_ebrw  \
# 4              22.2                22.8           60.0            540
#
#    sat_2018_math  sat_2018_total  act_2018_part  act_2018_composite
# 4            536            1076           27.0                22.7

# %%
plt.figure(figsize=(15, 10))
sat_bar_ca = plt.bar(['2017', '2018'], [final.at[4, 'sat_2017_part'], final.at[4, 'sat_2018_part']], align='edge', width=-.4)
act_bar_ca = plt.bar(['2017', '2018'], [final.at[4, 'act_2017_part'], final.at[4, 'act_2018_part']], align='edge', width=.4)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Participation (%)', fontsize=15)
plt.title('California\'s SAT and ACT Participation Rate', fontsize=20)
plt.legend(['SAT', 'ACT'], fontsize=15)

def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        plt.annotate(s='%d' % int(height),
                     xy=(bar.get_x() + bar.get_width()/2, 1.05+height),
                     ha='center',
                     va='bottom',
                     fontsize=15)

autolabel(sat_bar_ca)
autolabel(act_bar_ca);

# %% [markdown]
# Looking at California's participation rate, we can see that it's relatively high. Even though ACT participation rate is around 30%, there's an obvious demand for the SAT. We can take this opportunity to push for higher participation rates. California is primarily suitable to either secure a statewide testing contract or implement a SAT School Day because:
# -  They have their own standardized test: [Smarter Balanced Assessment](https://www.cde.ca.gov/ta/tg/sa/index.asp)
#     Neither College Board or ACT currently have a contract with the state of California. This means College Board will not have to wait until contract completion, unlike for states contracted with ACT.
# -  Again, securing a contract may take some time. College Board can implement a SAT School Day first. Given the 60% participation rate, students are already inclined to take the SAT, even when it's not one of their graduation requirements.

# %% [markdown]
# It would be beneficial to know the percentage of states that renewed their contracts and those that didn’t. Investigating the states that chose to renew their contracts with ACT and determining the reasoning behind such a decision can help highlight the areas in which the SAT is still lacking.
